# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
import pandas as pd
# Your code here - remember to use markdown cells for comments as well!
bom_df = pd.read_csv('zippedData/bom.movie_gross.csv.gz', compression='gzip')
bom_df.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
tmdb_movies_df = pd.read_csv('zippedData/tmdb.movies.csv.gz', compression='gzip')
tmdb_movies_df=tmdb_movies_df.rename(columns={'original_title':'title'})
#genre_IDs={12:'Adventure',16:'Animation',35:'Comedy',80:'Crime',99:'Documentary',18:'Drama', 10751:'Family',14:'Fantasy',
#           36:'History',27:'Horror',10402:'Music',9648:'Mystery',10749:'Romance',878:'Science Fiction',10770:'TV Movie',
#           53:'Thriller',10752:'War',37:'Western'}
#for i in range(len(tmdb_movies_df)):
#    for value in tmdb_movies_df.iloc[i]['genre_ids']:
#        if value in genre_IDs.keys():
#            tmdb_movies_df.loc[i]['genres']=genre_IDs[value]
tmdb_movies_df
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                               title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# ...

# %%
tm_budgets_df = pd.read_csv('zippedData/tn.movie_budgets.csv.gz', compression='gzip')
tm_budgets_df.head()
tm_budgets_df['production_budget'] = tm_budgets_df['production_budget'].str.replace(',','').str.replace('$','')
tm_budgets_df['domestic_gross'] = tm_budgets_df['domestic_gross'].str.replace(',','').str.replace('$','')
tm_budgets_df['worldwide_gross'] = tm_budgets_df['worldwide_gross'].str.replace(',','').str.replace('$','')
tm_budgets_df = tm_budgets_df.astype({'worldwide_gross':'float','domestic_gross':'float','production_budget':'float'})
tm_budgets_df['gross_per_$']=tm_budgets_df['worldwide_gross']/tm_budgets_df['production_budget']
tm_budgets_df=tm_budgets_df.sort_values(by='gross_per_$',ascending=False)
tm_budgets_df
# Out:
# C:\Users\hyper\AppData\Local\Temp\ipykernel_15316\2541676835.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   tm_budgets_df['production_budget'] = tm_budgets_df['production_budget'].str.replace(',','').str.replace('$','')
# C:\Users\hyper\AppData\Local\Temp\ipykernel_15316\2541676835.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   tm_budgets_df['domestic_gross'] = tm_budgets_df['domestic_gross'].str.replace(',','').str.replace('$','')
# ...

# %%
#dropping movies that made no money
#tm_budgets_df=tm_budgets_df.loc[tm_budgets_df['worldwide_gross']>10000]
#tm_budgets_df
# Out:
# C:\Users\hyper\AppData\Local\Temp\ipykernel_15316\3286383113.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   tm_budgets_df['production_budget'] = tm_budgets_df['production_budget'].str.replace(',','').str.replace('$','')
# C:\Users\hyper\AppData\Local\Temp\ipykernel_15316\3286383113.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   tm_budgets_df['domestic_gross'] = tm_budgets_df['domestic_gross'].str.replace(',','').str.replace('$','')
# ...

# %%
rt_info_df = pd.read_csv('zippedData/rt.movie_info.tsv.gz', delimiter='\t')
#rt_info_df = rt_info_df[0].str.split('\s\|\s', expand=True)
#rt_info_df.dropna()
rt_info_df.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# ...

# %%
rt_reviews_df = pd.read_csv('zippedData/rt.reviews.tsv.gz', delimiter='\t', encoding='iso-8859-1')
#rt_info_df = rt_info_df[0].str.split('\s\|\s', expand=True)
rt_reviews_df.head()
# Out:
#    id                                             review rating   fresh  \
# 0   3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1   3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2   3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3   3  Continuing along a line introduced in last yea...    NaN   fresh
# 4   3             ... a perverse twist on neorealism...     NaN   fresh
#
#            critic  top_critic         publisher               date
# 0      PJ Nabarro           0   Patrick Nabarro  November 10, 2018
# 1  Annalee Newitz           0           io9.com       May 23, 2018
# 2    Sean Axmaker           0  Stream on Demand    January 4, 2018
# 3   Daniel Kasman           0              MUBI  November 16, 2017
# 4             NaN           0      Cinema Scope   October 12, 2017

# %%
def read_sqlite(dbfile):
    import sqlite3
    from pandas import read_sql_query, read_sql_table
    with sqlite3.connect(dbfile) as dbcon:
        tables = list(read_sql_query("SELECT name FROM sqlite_master WHERE type='table';", dbcon)['name'])
        out = {tbl : read_sql_query(f"SELECT * from {tbl}", dbcon) for tbl in tables}
    return out
im_db=read_sqlite('zippedData/im.db')

# %%
print(im_db.keys())
# Out:
# dict_keys(['movie_basics', 'directors', 'known_for', 'movie_akas', 'movie_ratings', 'persons', 'principals', 'writers'])

# %%
imdb_basics=im_db['movie_basics']
imdb_basics=imdb_basics.rename(columns={'primary_title':'title'})
imdb_basics.head()
# Out:
#     movie_id                            title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
print(type(bom_df.iloc[0]['foreign_gross']))
bom_df=bom_df.dropna()
bom_df['foreign_gross'] = bom_df['foreign_gross'].str.replace(',','')
bom_df = bom_df.astype({'foreign_gross':'float','domestic_gross':'float'})
bom_df['total_gross']=bom_df['foreign_gross']+bom_df['domestic_gross']
bom_df
# Out:
# <class 'str'>
#                                                   title        studio  \
# 0                                           Toy Story 3            BV
# 1                            Alice in Wonderland (2010)            BV
# 2           Harry Potter and the Deathly Hallows Part 1            WB
# 3                                             Inception            WB
# 4                                   Shrek Forever After          P/DW
# ...                                                 ...           ...
# 3275                                    I Still See You           LGF
# 3286                              The Catcher Was a Spy           IFC
# 3309                                         Time Freak    Grindstone
# 3342  Reign of Judges: Title of Liberty - Concept Short  Darin Southa
# 3353            Antonio Lopez 1970: Sex Fashion & Disco            FM
#
#       domestic_gross  foreign_gross  year   total_gross
# ...

# %%
bom_df=bom_df.sort_values(by='total_gross', ascending=False)
bom_df.head()
len(bom_df)
# Out:
# 2007

# %%
#Find reviews of Cosmopolis (my fav film, #3 in the rt database)
cosmopolis_df=rt_reviews_df.loc[rt_reviews_df['id']==3]
cosmopolis_df.dropna()
# Out:
#      id                                             review rating   fresh  \
# 0     3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 6     3  Quickly grows repetitive and tiresome, meander...      C  rotten
# 7     3  Cronenberg is not a director to be daunted by ...    2/5  rotten
# 11    3  While not one of Cronenberg's stronger films, ...     B-   fresh
# 12    3  Robert Pattinson works mighty hard to make Cos...    2/4  rotten
# ..   ..                                                ...    ...     ...
# 149   3  A polemic rather than a film. Why Cronenberg t...   3/10  rotten
# 150   3  Its portrayal of civilisation as an impossibly...    4/5   fresh
# 151   3  Yes Cosmopolis bears a striking gloss, and is ...     C-  rotten
# 159   3  Threatens to soar and to be important, but it ...    3/5   fresh
# 161   3  [An] agonisingly self-conscious and meagre pie...    2/5  rotten
#
#                critic  top_critic             publisher               date
# ...
